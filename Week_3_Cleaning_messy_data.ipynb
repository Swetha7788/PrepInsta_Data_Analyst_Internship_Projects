# %% [markdown]
# **First Dataset**

# %%
import numpy as np
import pandas as pd

# %%
path="/content/drive/MyDrive/Data-cleaning-for-beginners-using-pandas.csv"
data=pd.read_csv(path)

# %%
data.head(20)
# Out:
#     Index   Age      Salary  Rating       Location  Established Easy_Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          22 non-null     float64
#  2   Salary       29 non-null     object
#  3   Rating       28 non-null     float64
#  4   Location     29 non-null     object
#  5   Established  29 non-null     int64
#  6   Easy_Apply   29 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.7+ KB

# %%
###For Easy_Apply
data.rename(columns = {'Easy Apply':'Easy_Apply'}, inplace = True)
data["Easy_Apply"]=data["Easy_Apply"].str.replace("-1","False")
data
# Out:
#     Index   Age      Salary  Rating       Location  Established Easy_Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1      False
# 3       3  64.0   $44k-$99k     4.4       India In         1988      False
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002      False
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1      False
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1      False
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1      False
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
####For Age columnn
avg_age=data['Age'].mean()
avg_age
data.Age.fillna(avg_age)
data['Age']=data.Age.fillna(avg_age)
data['Age']=data.Age.astype(int)
data
# Out:
#     Index  Age      Salary  Rating       Location  Established Easy_Apply
# 0       0   44   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1   66   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   39   $77k-$89k    -1.0    New York,Ny           -1      False
# 3       3   64   $44k-$99k     4.4       India In         1988      False
# 4       4   25   $44k-$99k     6.4  Australia Aus         2002      False
# 5       5   44   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6   21   $44k-$99k     0.0    New York,Ny           -1      False
# 7       7   44   $44k-$99k    -1.0  Australia Aus           -1      False
# 8       8   35   $44k-$99k     5.4    New York,Ny           -1      False
# 9       9   22   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10   55   $10k-$49k     5.4       India,In         2008       TRUE
# 11     11   44   $10k-$49k     6.7       India,In         2009      False
# ...

# %%
### For Salary column
data['Salary']=data.Salary.str.replace("$"," ")
data['Salary']=data.Salary.str.replace("k","000")
data[['Min_Salary', 'Max_Salary']] = data['Salary'].str.split('-', expand=True)
data = data.drop(columns=['Salary'])
data
# Out:
# <ipython-input-30-14844cbd8648>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Salary']=data.Salary.str.replace("$"," ")
#     Index  Age  Rating       Location  Established Easy_Apply Min_Salary  \
# 0       0   44     5.4       India,In         1999       TRUE      44000
# 1       1   66     3.5    New York,Ny         2002       TRUE      55000
# 2       2   39    -1.0    New York,Ny           -1      False      77000
# 3       3   64     4.4       India In         1988      False      44000
# 4       4   25     6.4  Australia Aus         2002      False      44000
# 5       5   44     1.4       India,In         1999       TRUE      77000
# 6       6   21     0.0    New York,Ny           -1      False      44000
# 7       7   44    -1.0  Australia Aus           -1      False      44000
# ...

# %%
### For Rating Column
data["Rating"] = data["Rating"].replace(-1.0, np.nan)
avg_rating=data['Rating'].mean()
data['Rating']=data.Rating.fillna(avg_rating)
data['Rating']=data.Rating.round(decimals=1)
data
# Out:
#     Index  Age  Rating       Location  Established Easy_Apply Min_Salary  \
# 0       0   44     5.4       India,In         1999       TRUE      44000
# 1       1   66     3.5    New York,Ny         2002       TRUE      55000
# 2       2   39     4.3    New York,Ny           -1      False      77000
# 3       3   64     4.4       India In         1988      False      44000
# 4       4   25     6.4  Australia Aus         2002      False      44000
# 5       5   44     1.4       India,In         1999       TRUE      77000
# 6       6   21     0.0    New York,Ny           -1      False      44000
# 7       7   44     4.3  Australia Aus           -1      False      44000
# 8       8   35     5.4    New York,Ny           -1      False      44000
# 9       9   22     7.7       India,In           -1       TRUE      44000
# 10     10   55     5.4       India,In         2008       TRUE      10000
# 11     11   44     6.7       India,In         2009      False      10000
# ...

# %%
###For Location Column
data[['Location','Country_initials']] = data['Location'].str.split(',', expand=True)
data['Location']=data.Location.str.replace(" Aus"," ")
data['Country_initials']=data.Country_initials.str.replace("None","Aus")
data['Country_initials']=data.Country_initials.fillna('Aus')
data
# Out:
#     Index  Age  Rating    Location  Established Easy_Apply Min_Salary  \
# 0       0   44     5.4       India         1999       TRUE      44000
# 1       1   66     3.5    New York         2002       TRUE      55000
# 2       2   39     4.3    New York           -1      False      77000
# 3       3   64     4.4    India In         1988      False      44000
# 4       4   25     6.4  Australia          2002      False      44000
# 5       5   44     1.4       India         1999       TRUE      77000
# 6       6   21     0.0    New York           -1      False      44000
# 7       7   44     4.3  Australia            -1      False      44000
# 8       8   35     5.4    New York           -1      False      44000
# 9       9   22     7.7       India           -1       TRUE      44000
# 10     10   55     5.4       India         2008       TRUE      10000
# 11     11   44     6.7       India         2009      False      10000
# ...

# %%
###For Established Column
data["Established"]=data["Established"].astype(str)
data["Established"] = data["Established"].str.replace('-1','Unknown')
data
# Out:
#     Index  Age  Rating    Location Established Easy_Apply Min_Salary  \
# 0       0   44     5.4       India        1999       TRUE      44000
# 1       1   66     3.5    New York        2002       TRUE      55000
# 2       2   39     4.3    New York     Unknown      False      77000
# 3       3   64     4.4    India In        1988      False      44000
# 4       4   25     6.4  Australia         2002      False      44000
# 5       5   44     1.4       India        1999       TRUE      77000
# 6       6   21     0.0    New York     Unknown      False      44000
# 7       7   44     4.3  Australia      Unknown      False      44000
# 8       8   35     5.4    New York     Unknown      False      44000
# 9       9   22     7.7       India     Unknown       TRUE      44000
# 10     10   55     5.4       India        2008       TRUE      10000
# 11     11   44     6.7       India        2009      False      10000
# 12     12   39     0.0       India        1999      False      44000
# ...

# %%
new_columns=['Age','Rating','Location','Country_initials','Established','Easy_Apply','Min_Salary','Max_Salary']
data=data[new_columns]
data
# Out:
#     Age  Rating    Location Country_initials Established Easy_Apply  \
# 0    44     5.4       India               In        1999       TRUE
# 1    66     3.5    New York               Ny        2002       TRUE
# 2    39     4.3    New York               Ny     Unknown      False
# 3    64     4.4    India In              Aus        1988      False
# 4    25     6.4  Australia               Aus        2002      False
# 5    44     1.4       India               In        1999       TRUE
# 6    21     0.0    New York               Ny     Unknown      False
# 7    44     4.3  Australia               Aus     Unknown      False
# 8    35     5.4    New York               Ny     Unknown      False
# 9    22     7.7       India               In     Unknown       TRUE
# 10   55     5.4       India               In        2008       TRUE
# 11   44     6.7       India               In        2009      False
# 12   39     0.0       India               In        1999      False
# ...

# %% [markdown]
# **Second dataset**

# %%
### Second dataset
path='/content/drive/MyDrive/chipotle.tsv'
df=pd.read_csv(path,sep='\t')

# %%
df.isnull().sum()
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
df.tail(20)
# Out:
#       order_id  quantity            item_name  \
# 4602      1827         1     Barbacoa Burrito
# 4603      1827         1     Barbacoa Burrito
# 4604      1828         1         Chicken Bowl
# 4605      1828         1  Chips and Guacamole
# 4606      1828         1    Canned Soft Drink
# 4607      1829         1        Steak Burrito
# 4608      1829         1       Veggie Burrito
# 4609      1829         1    Canned Soft Drink
# 4610      1830         1        Steak Burrito
# 4611      1830         1       Veggie Burrito
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# ...

# %%
df['item_price']=df.item_price.str.replace("$"," ")
df
# Out:
# <ipython-input-40-568912aa4de8>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['item_price']=df.item_price.str.replace("$"," ")
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# ...

# %%
df['choice_description']=df.choice_description.str.replace("["," ")
df['choice_description']=df.choice_description.str.replace("]"," ")
df['choice_description']= df['choice_description'].replace(np.nan, None)
df.head(10)
# Out:
# <ipython-input-41-ae86b5b386e6>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['choice_description']=df.choice_description.str.replace("["," ")
# <ipython-input-41-ae86b5b386e6>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['choice_description']=df.choice_description.str.replace("]"," ")
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# ...

# %%
df[['choice_0','choice_1','choice_2','choice_3','choice_4','choice_5','choice_6','choice_7','choice_8','choice_9']]=df['choice_description'].str.split("," ,expand=True)
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                  None      2.39
# ...

# %%
new_columns=['order_id','quantity','item_name','choice_description','choice_0','choice_2','choice_3','choice_4','choice_5','choice_6','choice_7','choice_8','choice_9']
df=df[new_columns]
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  \
# 0                                                  None
# 1                                           Clementine
# ...

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  \
# 0                                               None
# 1                                        Clementine
# 2                                             Apple
# 3                                               None
# ...
